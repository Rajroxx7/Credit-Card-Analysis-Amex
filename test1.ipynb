# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("development_dataset.csv")

# %%
data.head()
# Out:
#    VAR1        VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0     1  828.235294  0.138889  321.428571  625.911006  1.818182  1.081550
# 1     2  911.764706  0.027778         NaN  611.574748  8.181818  1.344479
# 2     3  962.352941  0.833333   35.714286  615.825381  8.181818  0.720796
# 3     4  892.941177       NaN         NaN  638.076431  9.090909  0.820218
# 4     5  914.117647  0.083333         NaN  626.514988  5.181818  1.372928
#
#          VAR8       VAR9      VAR10   ...         VAR12  VAR13  VAR14 VAR15  \
# 0  198.113469        NaN  58.632548   ...    100.083403    1.0      1   1.0
# 1  198.600020  22.086661        NaN   ...     15.012510    NaN      1   NaN
# 2  197.267767        NaN  58.632548   ...    210.175146   10.0      1  10.0
# 3  197.355744   4.363431  58.632548   ...           NaN    NaN      1   NaN
# 4  198.790477  85.938202  58.632548   ...    210.175146    NaN      .   NaN
#
#       VAR16  VAR17  VAR18  VAR19       VAR20   VAR21
# ...

# %%
test=pd.read_csv("leaderboard_dataset.csv")

# %%
test
# Out:
#        VAR1        VAR2       VAR3         VAR4        VAR5       VAR6  \
# 0         1  878.823529   0.833333   821.428571  620.835806   5.181818
# 1         2  891.764706   0.138889   357.142857  614.092215   3.909091
# 2         3  955.294118   0.055556          NaN  611.574748   6.363636
# 3         4  831.764706   0.111111   250.000000  617.740617   6.545455
# 4         5  957.647059   0.166667          NaN  623.426802        NaN
# 5         6  890.588235   0.138889   107.142857  611.574748  10.909091
# 6         7  923.529412   0.013889    71.428571  648.165558  11.363636
# 7         8  881.176471   0.083333   285.714286  599.039931  11.363636
# 8         9  960.000000   0.333333          NaN  612.078941  11.818182
# 9        10  876.470588        NaN          NaN  641.218888   6.363636
# 10       11  897.647059   0.388889   571.428571  611.574748   6.636364
# 11       12  829.411765   1.666667   142.857143  648.958612  31.818182
# ...

# %%
test.isnull().sum()
# Out:
# VAR1        0
# VAR2      267
# VAR3      937
# VAR4     3686
# VAR5        0
# VAR6     1058
# VAR7      215
# VAR8      215
# VAR9     4701
# VAR10    1348
# VAR11    2231
# VAR12    3201
# VAR13    2493
# VAR14       0
# VAR15    2359
# VAR16     229
# VAR17    6543
# VAR18       0
# VAR19       0
# VAR20       0
# dtype: int64

# %%
data['VAR14']=data['VAR14'].replace('.','1')
data['VAR2'].fillna(data['VAR2'].mean(),inplace=True)
#data[data['VAR3']<0.1].VAR3.hist()
data['VAR5'].fillna(data['VAR5'].value_counts().idxmax(),inplace=True)
data1=data.drop('VAR17',axis=1)
data1=data1.drop('VAR9',axis=1)
data1['VAR6'].fillna(data1['VAR6'].median(),inplace=True)
data1['VAR7'].fillna(data1['VAR7'].median(),inplace=True)
data1['VAR8'].fillna(data1['VAR8'].median(),inplace=True)
data1['VAR10'].fillna(data1['VAR10'].mean(),inplace=True)
data1['VAR11'].fillna(data1['VAR11'].median(),inplace=True)
data1['VAR12'].fillna(data1['VAR12'].mean(),inplace=True)
data1['VAR13'].fillna(data1[data1['VAR13']<20].VAR13.mean(),inplace=True)
data1['VAR15'].fillna(data1[data1['VAR15']<40].VAR15.mean(),inplace=True)
data1['VAR16'].fillna(data1.VAR16.median(),inplace=True)
data1['VAR4'].fillna(data1.VAR4.median(),inplace=True)
t=data1['VAR3']
t=np.log(t)
t.fillna(t.mean(),inplace=True)
y=np.exp(t)
data1['VAR3']=y

# %%
data2=data1.drop('VAR1',axis=1)
data2.head()
# Out:
#          VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0  828.235294  0.138889  321.428571  625.911006  1.818182  1.081550
# 1  911.764706  0.027778  142.857143  611.574748  8.181818  1.344479
# 2  962.352941  0.833333   35.714286  615.825381  8.181818  0.720796
# 3  892.941177  0.218990  142.857143  638.076431  9.090909  0.820218
# 4  914.117647  0.083333  142.857143  626.514988  5.181818  1.372928
#
#          VAR8      VAR10     VAR11       VAR12     VAR13 VAR14     VAR15  \
# 0  198.113469  58.632548  0.279273  100.083403   1.00000     1   1.00000
# 1  198.600020  56.497320  2.098360   15.012510   8.97705     1  11.59601
# 2  197.267767  58.632548  0.453212  210.175146  10.00000     1  10.00000
# 3  197.355744  58.632548  2.098360  117.283667   8.97705     1  11.59601
# 4  198.790477  58.632548  2.098360  210.175146   8.97705     1  11.59601
#
#       VAR16  VAR18  VAR19       VAR20   VAR21
# 0  1.540594      1      0  100.104991     Low
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=data2.drop('VAR21',axis=1)

# %%
y=data2['VAR21']

# %%
X.shape
# Out:
# (34000, 17)

# %%
y.shape
# Out:
# (34000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (27200, 17)
# (27200,)
# (6800, 17)
# (6800,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
#accuracy={}
#accuracy_list=[]
#k_range = range(1,200)
#for k in k_range:
model=KNeighborsClassifier(n_neighbors=65,weights='distance')
    #model.fit(X_train,y_train)
    #pred=model.predict(X_test)
    #accuracy[k]=metrics.accuracy_score(pred,y_test)
    #accuracy_list.append(metrics.accuracy_score(pred,y_test))
    
#plt.plot(k_range,accuracy_list)
#plt.xlabel('k_range')
#plt.ylabel('accuracy_list')

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=65, p=2,
#            weights='distance')

# %%
pred=model.predict(X_test)

# %%
print(metrics.accuracy_score(pred,y_test))
# Out:
# 0.5585294117647058

# %%
X.head()
# Out:
#          VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0  828.235294  0.138889  321.428571  625.911006  1.818182  1.081550
# 1  911.764706  0.027778  142.857143  611.574748  8.181818  1.344479
# 2  962.352941  0.833333   35.714286  615.825381  8.181818  0.720796
# 3  892.941177  0.218990  142.857143  638.076431  9.090909  0.820218
# 4  914.117647  0.083333  142.857143  626.514988  5.181818  1.372928
#
#          VAR8      VAR10     VAR11       VAR12     VAR13 VAR14     VAR15  \
# 0  198.113469  58.632548  0.279273  100.083403   1.00000     1   1.00000
# 1  198.600020  56.497320  2.098360   15.012510   8.97705     1  11.59601
# 2  197.267767  58.632548  0.453212  210.175146  10.00000     1  10.00000
# 3  197.355744  58.632548  2.098360  117.283667   8.97705     1  11.59601
# 4  198.790477  58.632548  2.098360  210.175146   8.97705     1  11.59601
#
#       VAR16  VAR18  VAR19       VAR20
# 0  1.540594      1      0  100.104991
# 1  1.614613      0      1  146.654045
# ...

# %%
data.head()
# Out:
#    VAR1        VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0     1  828.235294  0.138889  321.428571  625.911006  1.818182  1.081550
# 1     2  911.764706  0.027778         NaN  611.574748  8.181818  1.344479
# 2     3  962.352941  0.833333   35.714286  615.825381  8.181818  0.720796
# 3     4  892.941177       NaN         NaN  638.076431  9.090909  0.820218
# 4     5  914.117647  0.083333         NaN  626.514988  5.181818  1.372928
#
#          VAR8       VAR9      VAR10   ...         VAR12  VAR13  VAR14 VAR15  \
# 0  198.113469        NaN  58.632548   ...    100.083403    1.0      1   1.0
# 1  198.600020  22.086661        NaN   ...     15.012510    NaN      1   NaN
# 2  197.267767        NaN  58.632548   ...    210.175146   10.0      1  10.0
# 3  197.355744   4.363431  58.632548   ...           NaN    NaN      1   NaN
# 4  198.790477  85.938202  58.632548   ...    210.175146    NaN      1   NaN
#
#       VAR16  VAR17  VAR18  VAR19       VAR20   VAR21
# ...

# %%
data3=data
del data3['VAR21']

# %%
data3.head()
# Out:
#    VAR1        VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0     1  828.235294  0.138889  321.428571  625.911006  1.818182  1.081550
# 1     2  911.764706  0.027778         NaN  611.574748  8.181818  1.344479
# 2     3  962.352941  0.833333   35.714286  615.825381  8.181818  0.720796
# 3     4  892.941177       NaN         NaN  638.076431  9.090909  0.820218
# 4     5  914.117647  0.083333         NaN  626.514988  5.181818  1.372928
#
#          VAR8       VAR9      VAR10     VAR11       VAR12  VAR13 VAR14  VAR15  \
# 0  198.113469        NaN  58.632548  0.279273  100.083403    1.0     1    1.0
# 1  198.600020  22.086661        NaN       NaN   15.012510    NaN     1    NaN
# 2  197.267767        NaN  58.632548  0.453212  210.175146   10.0     1   10.0
# 3  197.355744   4.363431  58.632548       NaN         NaN    NaN     1    NaN
# 4  198.790477  85.938202  58.632548       NaN  210.175146    NaN     1    NaN
#
#       VAR16  VAR17  VAR18  VAR19       VAR20
# ...

# %%
test1=test
test.shape
# Out:
# (10000, 20)

# %%
test1.head()
# Out:
#    VAR1        VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0     1  878.823529  0.833333  821.428571  620.835806  5.181818  0.833974
# 1     2  891.764706  0.138889  357.142857  614.092215  3.909091  0.595187
# 2     3  955.294118  0.055556         NaN  611.574748  6.363636  0.918652
# 3     4  831.764706  0.111111  250.000000  617.740617  6.545455  2.383924
# 4     5  957.647059  0.166667         NaN  623.426802       NaN  0.711240
#
#          VAR8        VAR9      VAR10      VAR11      VAR12      VAR13 VAR14  \
# 0  197.500187         NaN  58.632548   9.433609  40.033361  10.000000     2
# 1  197.016843  253.896073  58.632548  10.144612        NaN   5.666667     1
# 2  197.660051   22.086661        NaN   0.583494        NaN   6.000000     1
# 3  200.526288         NaN  48.539365        NaN        NaN        NaN     3
# 4  197.151458    5.013668  49.379748   0.255712        NaN  13.333333     1
#
#        VAR15     VAR16    VAR17  VAR18  VAR19       VAR20
# ...

# %%
data4=[test,data3]
comb1=pd.concat(data4)

# %%
comb1.head(10)
# Out:
#    VAR1        VAR2      VAR3        VAR4        VAR5       VAR6      VAR7  \
# 0     1  878.823529  0.833333  821.428571  620.835806   5.181818  0.833974
# 1     2  891.764706  0.138889  357.142857  614.092215   3.909091  0.595187
# 2     3  955.294118  0.055556         NaN  611.574748   6.363636  0.918652
# 3     4  831.764706  0.111111  250.000000  617.740617   6.545455  2.383924
# 4     5  957.647059  0.166667         NaN  623.426802        NaN  0.711240
# 5     6  890.588235  0.138889  107.142857  611.574748  10.909091  0.681405
# 6     7  923.529412  0.013889   71.428571  648.165558  11.363636  1.092656
# 7     8  881.176471  0.083333  285.714286  599.039931  11.363636  0.720824
# 8     9  960.000000  0.333333         NaN  612.078941  11.818182  0.564360
# 9    10  876.470588       NaN         NaN  641.218888   6.363636  0.633561
#
#          VAR8        VAR9      VAR10      VAR11       VAR12      VAR13 VAR14  \
# ...

# %%
comb1.isnull().sum()
# Out:
# VAR1         0
# VAR2       267
# VAR3      4322
# VAR4     16180
# VAR5         0
# VAR6      4553
# VAR7      1050
# VAR8      1050
# VAR9     20518
# VAR10     5898
# VAR11     9796
# VAR12    13703
# VAR13    11015
# VAR14        0
# VAR15    10383
# VAR16     1095
# VAR17    28737
# VAR18        0
# VAR19        0
# VAR20        0
# dtype: int64

# %%
comb1['VAR14']=comb1['VAR14'].replace('.','1')
comb1['VAR2'].fillna(comb1['VAR2'].mean(),inplace=True)
#data[data['VAR3']<0.1].VAR3.hist()
comb1['VAR5'].fillna(comb1['VAR5'].value_counts().idxmax(),inplace=True)
comb2=comb1.drop('VAR17',axis=1)
comb2=comb2.drop('VAR9',axis=1)
comb2['VAR6'].fillna(comb2['VAR6'].median(),inplace=True)
comb2['VAR7'].fillna(comb2['VAR7'].median(),inplace=True)
comb2['VAR8'].fillna(comb2['VAR8'].median(),inplace=True)
comb2['VAR10'].fillna(comb2['VAR10'].mean(),inplace=True)
comb2['VAR11'].fillna(comb2['VAR11'].median(),inplace=True)
comb2['VAR12'].fillna(comb2['VAR12'].mean(),inplace=True)
comb2['VAR13'].fillna(comb2[comb2['VAR13']<20].VAR13.mean(),inplace=True)
comb2['VAR15'].fillna(comb2[comb2['VAR15']<40].VAR15.mean(),inplace=True)
comb2['VAR16'].fillna(comb2.VAR16.median(),inplace=True)
comb2['VAR4'].fillna(comb2.VAR4.median(),inplace=True)
t=comb2['VAR3']
t=np.log(t)
t.fillna(t.mean(),inplace=True)
y=np.exp(t)
comb2['VAR3']=y
comb2.isnull().sum()
# Out:
# VAR1     0
# VAR2     0
# VAR3     0
# VAR4     0
# VAR5     0
# VAR6     0
# VAR7     0
# VAR8     0
# VAR10    0
# VAR11    0
# VAR12    0
# VAR13    0
# VAR14    0
# VAR15    0
# VAR16    0
# VAR18    0
# VAR19    0
# VAR20    0
# dtype: int64

# %%
comb3=comb2.drop('VAR1',axis=1)
comb3.head()
# Out:
#          VAR2      VAR3        VAR4        VAR5       VAR6      VAR7  \
# 0  878.823529  0.833333  821.428571  620.835806   5.181818  0.833974
# 1  891.764706  0.138889  357.142857  614.092215   3.909091  0.595187
# 2  955.294118  0.055556  142.857143  611.574748   6.363636  0.918652
# 3  831.764706  0.111111  250.000000  617.740617   6.545455  2.383924
# 4  957.647059  0.166667  142.857143  623.426802  10.000000  0.711240
#
#          VAR8      VAR10      VAR11       VAR12      VAR13 VAR14      VAR15  \
# 0  197.500187  58.632548   9.433609   40.033361  10.000000     2  10.000000
# 1  197.016843  58.632548  10.144612  116.720860   5.666667     1   7.600000
# 2  197.660051  56.482613   0.583494  116.720860   6.000000     1   6.000000
# 3  200.526288  48.539365   2.098360  116.720860   8.988806     3  11.614667
# 4  197.151458  49.379748   0.255712  116.720860  13.333333     1  13.333333
#
#       VAR16  VAR18  VAR19       VAR20
# 0  1.212784      1      0   48.099828
# ...

# %%
comb3.shape
# Out:
# (44000, 17)

# %%
test2=comb3.iloc[0:10000,:]
test2.head()
# Out:
#          VAR2      VAR3        VAR4        VAR5       VAR6      VAR7  \
# 0  878.823529  0.833333  821.428571  620.835806   5.181818  0.833974
# 1  891.764706  0.138889  357.142857  614.092215   3.909091  0.595187
# 2  955.294118  0.055556  142.857143  611.574748   6.363636  0.918652
# 3  831.764706  0.111111  250.000000  617.740617   6.545455  2.383924
# 4  957.647059  0.166667  142.857143  623.426802  10.000000  0.711240
#
#          VAR8      VAR10      VAR11       VAR12      VAR13 VAR14      VAR15  \
# 0  197.500187  58.632548   9.433609   40.033361  10.000000     2  10.000000
# 1  197.016843  58.632548  10.144612  116.720860   5.666667     1   7.600000
# 2  197.660051  56.482613   0.583494  116.720860   6.000000     1   6.000000
# 3  200.526288  48.539365   2.098360  116.720860   8.988806     3  11.614667
# 4  197.151458  49.379748   0.255712  116.720860  13.333333     1  13.333333
#
#       VAR16  VAR18  VAR19       VAR20
# 0  1.212784      1      0   48.099828
# ...

# %%
final_pred=model.predict(test2)

# %%
final_pred.shape
# Out:
# (10000,)

# %%
test.head()
# Out:
#    VAR1        VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0     1  878.823529  0.833333  821.428571  620.835806  5.181818  0.833974
# 1     2  891.764706  0.138889  357.142857  614.092215  3.909091  0.595187
# 2     3  955.294118  0.055556         NaN  611.574748  6.363636  0.918652
# 3     4  831.764706  0.111111  250.000000  617.740617  6.545455  2.383924
# 4     5  957.647059  0.166667         NaN  623.426802       NaN  0.711240
#
#          VAR8        VAR9      VAR10      VAR11      VAR12      VAR13 VAR14  \
# 0  197.500187         NaN  58.632548   9.433609  40.033361  10.000000     2
# 1  197.016843  253.896073  58.632548  10.144612        NaN   5.666667     1
# 2  197.660051   22.086661        NaN   0.583494        NaN   6.000000     1
# 3  200.526288         NaN  48.539365        NaN        NaN        NaN     3
# 4  197.151458    5.013668  49.379748   0.255712        NaN  13.333333     1
#
#        VAR15     VAR16    VAR17  VAR18  VAR19       VAR20
# ...

# %%
test['VAR21']=final_pred

# %%
test.head()
# Out:
#    VAR1        VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0     1  878.823529  0.833333  821.428571  620.835806  5.181818  0.833974
# 1     2  891.764706  0.138889  357.142857  614.092215  3.909091  0.595187
# 2     3  955.294118  0.055556         NaN  611.574748  6.363636  0.918652
# 3     4  831.764706  0.111111  250.000000  617.740617  6.545455  2.383924
# 4     5  957.647059  0.166667         NaN  623.426802       NaN  0.711240
#
#          VAR8        VAR9      VAR10   ...        VAR12      VAR13  VAR14  \
# 0  197.500187         NaN  58.632548   ...    40.033361  10.000000      2
# 1  197.016843  253.896073  58.632548   ...          NaN   5.666667      1
# 2  197.660051   22.086661        NaN   ...          NaN   6.000000      1
# 3  200.526288         NaN  48.539365   ...          NaN        NaN      3
# 4  197.151458    5.013668  49.379748   ...          NaN  13.333333      1
#
#        VAR15     VAR16    VAR17  VAR18  VAR19       VAR20   VAR21
# ...

# %%
solution1=test[['VAR1','VAR21']]

# %%
solution1.head()
# Out:
#    VAR1   VAR21
# 0     1  Medium
# 1     2     Low
# 2     3  Medium
# 3     4  Medium
# 4     5  Medium

# %%
solution1
# Out:
#        VAR1   VAR21
# 0         1  Medium
# 1         2     Low
# 2         3  Medium
# 3         4  Medium
# 4         5  Medium
# 5         6  Medium
# 6         7  Medium
# 7         8     Low
# 8         9  Medium
# 9        10  Medium
# 10       11  Medium
# 11       12  Medium
# 12       13  Medium
# 13       14  Medium
# 14       15     Low
# 15       16  Medium
# 16       17  Medium
# 17       18  Medium
# 18       19     Low
# 19       20  Medium
# 20       21  Medium
# 21       22     Low
# 22       23  Medium
# 23       24     Low
# 24       25  Medium
# 25       26  Medium
# 26       27  Medium
# 27       28  Medium
# 28       29  Medium
# 29       30  Medium
# ...     ...     ...
# 9970   9971  Medium
# 9971   9972  Medium
# 9972   9973  Medium
# 9973   9974  Medium
# 9974   9975  Medium
# 9975   9976  Medium
# 9976   9977  Medium
# 9977   9978     Low
# 9978   9979  Medium
# 9979   9980  Medium
# 9980   9981  Medium
# 9981   9982     Low
# 9982   9983     Low
# ...

# %%
solution1.head()
# Out:
#    VAR1   VAR21
# 0     1  Medium
# 1     2     Low
# 2     3  Medium
# 3     4  Medium
# 4     5  Medium

# %%
export_csv = solution1.to_csv (r'RandomVariable_3.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
